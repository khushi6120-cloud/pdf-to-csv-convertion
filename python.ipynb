# %%
import pandas as pd
import re

# %%
import pandas as pd

# %%
dff=pd.DataFrame(dtype=object,columns=['vuln','severity','Description','URL','Method','Parameter','Attack','Evidence','Instances','Solution','Reference','CWE Id','WASC Id','Plugin Id'])

# %%
dff.head()
# Out:
# Empty DataFrame
# Columns: [vuln, severity, Description, URL, Method, Parameter, Attack, Evidence, Instances, Solution, Reference, CWE Id, WASC Id, Plugin Id]
# Index: []

# %%
df2=pd.read_csv("sbb.csv")

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=990, step=1)

# %%
dff.shape
# Out:
# (0, 14)

# %%
dff.head()
# Out:
# Empty DataFrame
# Columns: [vuln, severity, Description, URL, Method, Parameter, Attack, Evidence, Instances, Solution, Reference, CWE Id, WASC Id, Plugin Id]
# Index: []

# %%
df2.head()
# Out:
#           High                             Anti-CSRF Tokens Check
# 0  Description  A cross-site request forgery is an attack that...
# 1          URL       https://www.secureblink.com/company-register
# 2       Method                                                GET
# 3    Parameter                                                NaN
# 4       Attack                                                NaN

# %%
for r in df2.index:
    if pd.isnull(df2["High"][r]):
        df2.drop(r,inplace=True)

# %%
for r in df2.index:
    if pd.isnull(df2["High"][r]):
        print(r)

# %%
dobj={"severity":"","Risk level":"","Description":"","site":[],"Instances":"","Solution":"","Reference":"","CWE Id":"","WASC Id":"","Plugin Id":""}
siteobj={"URL":"","Method":"","Parameter":"","Attack":"","Evidence":""}
d=[]

# %%
tempd=dobj.copy()
tempd["severity"]=df2.columns.values[0]
tempd["vname"]=df2.columns.values[1]
currsite=siteobj.copy()
df2.rename(columns={"High":"c1","Anti-CSRF Tokens Check":"c2"},inplace=True)
for r in df2.index:
    #print(df2["c1"][r])
    if df2["c1"][r]=="Plugin Id":
        tempd[df2["c1"][r]]=df2["c2"][r]
        d.append(tempd)
        tempd=dobj.copy()
        tempd["site"]=[]
    else:
        if df2["c1"][r] in siteobj:
            if df2["c1"][r]=="Evidence":
                currsite["Evidence"]=df2["c2"][r]
                tempd["site"].append(currsite)
                currsite=siteobj.copy()
            else:
                currsite[df2["c1"][r]]=df2["c2"][r]
        elif df2["c1"][r] in {"High","Low","Medium","Informational"}:
            tempd["severity"]=df2["c1"][r]
            tempd["vname"]=df2["c2"][r]
        else:
            tempd[df2["c1"][r]]=df2["c2"][r]

# %%
c=1
for row in d:
    print(row["Risk level"])
    c+=1
    print(len(row["site"]))
# Out:
# 12
#
# 2
#
# 1
#
# 9
#
# 12
#
# 11
#
# 12
#
# 3
#
# 12
#
# 12
#
# 3
#
# 10
#
# 3
#
# 17
#
# 1
#
# 10
#
# 11
#
# 11
#
# 11

# %%
dff.rename(columns={"vuln":"severity","severity":"vname"},inplace=True)

# %%
dff
# Out:
# Empty DataFrame
# Columns: [severity, vname, Description, URL, Method, Parameter, Attack, Evidence, Instances, Solution, Reference, CWE Id, WASC Id, Plugin Id]
# Index: []

# %%
for row in d:
    dff= dff.loc[:,~dff.columns.duplicated()]
    for u in row["site"]:
        temp={}
        for key in row:
            if key!="site":
                temp[key]=row[key]
        for ukey in u:
            temp[ukey]=u[ukey]
            
        
        dff=dff.append(temp,ignore_index=True)

# %%
dff.shape
# Out:
# (163, 16)

# %%
dff
# Out:
#           severity                   vname  \
# 0             High  Anti-CSRF Tokens Check
# 1             High  Anti-CSRF Tokens Check
# 2             High  Anti-CSRF Tokens Check
# 3             High  Anti-CSRF Tokens Check
# 4             High  Anti-CSRF Tokens Check
# ..             ...                     ...
# 158  Informational    Retrieved from Cache
# 159  Informational    Retrieved from Cache
# 160  Informational    Retrieved from Cache
# 161  Informational    Retrieved from Cache
# 162  Informational    Retrieved from Cache
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.drop(columns=dff.columns[-1], 
        axis=1, 
        inplace=True)

# %%
dff
# Out:
#           severity                   vname  \
# 0             High  Anti-CSRF Tokens Check
# 1             High  Anti-CSRF Tokens Check
# 2             High  Anti-CSRF Tokens Check
# 3             High  Anti-CSRF Tokens Check
# 4             High  Anti-CSRF Tokens Check
# ..             ...                     ...
# 158  Informational    Retrieved from Cache
# 159  Informational    Retrieved from Cache
# 160  Informational    Retrieved from Cache
# 161  Informational    Retrieved from Cache
# 162  Informational    Retrieved from Cache
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.to_csv('sb.csv')

# %%
dff
# Out:
#           severity                   vname  \
# 0             High  Anti-CSRF Tokens Check
# 1             High  Anti-CSRF Tokens Check
# 2             High  Anti-CSRF Tokens Check
# 3             High  Anti-CSRF Tokens Check
# 4             High  Anti-CSRF Tokens Check
# ..             ...                     ...
# 158  Informational    Retrieved from Cache
# 159  Informational    Retrieved from Cache
# 160  Informational    Retrieved from Cache
# 161  Informational    Retrieved from Cache
# 162  Informational    Retrieved from Cache
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.iloc[:,:-1]
# Out:
#           severity                   vname  \
# 0             High  Anti-CSRF Tokens Check
# 1             High  Anti-CSRF Tokens Check
# 2             High  Anti-CSRF Tokens Check
# 3             High  Anti-CSRF Tokens Check
# 4             High  Anti-CSRF Tokens Check
# ..             ...                     ...
# 158  Informational    Retrieved from Cache
# 159  Informational    Retrieved from Cache
# 160  Informational    Retrieved from Cache
# 161  Informational    Retrieved from Cache
# 162  Informational    Retrieved from Cache
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
first_column = dff.pop('vname')

# %%
dff.insert(0, 'vname', first_column)

# %%
print()
print("After Shifting column to first position")
display(dff)
# Out:
# After Shifting column to first position
#                       vname       severity  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.drop(['Parameter','Attack','Plugin Id','Risk level'],axis = 1, inplace=True)

# %%
dff
# Out:
#                       vname       severity  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.rename(columns = {'Evidence':'Responce'}, inplace = True)

# %%
dff
# Out:
#                       vname       severity  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
# dff.rename(columns = {'Method':'Request Header'}, inplace = True)

# %%
# dff

# %%
dff.get('URL')
# Out:
# 0           https://www.secureblink.com/company-register
# 1      https://www.secureblink.com/company-register?c...
# 2                 https://www.secureblink.com/contact-us
# 3      https://www.secureblink.com/contact-us?company...
# 4                   https://www.secureblink.com/register
#                              ...
# 158              https://www.secureblink.com/sitemap.xml
# 159                https://www.secureblink.com/solutions
# 160          https://www.secureblink.com/threat-research
# 161               https://www.secureblink.com/threat-spy
# 162              https://www.secureblink.com/white-paper
# Name: URL, Length: 163, dtype: object

# %%
dff['Request Header'] = dff['URL'] 
dff['Request Header'] = dff.loc[:, 'URL']

# %%
dff
# Out:
#                       vname       severity  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.rename(columns = {'Method':'Request Header'}, inplace = True)

# %%
dff
# Out:
#                       vname       severity  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.drop(['Method','Parameter','Attack','Evidence','Plugin Id','Risk level'],axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1404-81da6c6af03d> in <module>
# ----> 1 dff.drop(['Method','Parameter','Attack','Evidence','Plugin Id','Risk level'],axis = 1, inplace=True)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
dff
# Out:
#                       vname       severity  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
# dff.columns =['severity', 'Risk level']

# %%
dff.rename(columns = {'severity':'Risk level'}, inplace = True)

# %%
dff
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.get('Anti-CSRF Tokens Check')

# %%
str=""

for x in url.itertuples():
    if(x[2]!=''):
        str=str+x[2]+','
#     print(x[2])

print(str)
# Out:
# bar%40example.com&message&name=ZAP&phone=9999999999,https://www.secureblink.com/white-paper?email=foo-bar%40example.com&name=ZAP&phone=9999999999,https://www.secureblink.com/,https://www.secureblink.com/about-us,https://www.secureblink.com/blog,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/,https://www.secureblink.com/about-us,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/,https://www.
# ...

# %%
for x in dff.itertuples():
    
    print(x[1])
# Out:
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# SQL Injection - SQLite
# SQL Injection - SQLite
# Application Error Disclosure
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Missing Anti-clickjacking Header
# Missing Anti-clickjacking Header
# Missing Anti-clickjacking Header
# ...

# %%
dff
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
for i in range(len(dff)-1):
    if dff.loc[i,'vname']==dff.loc[i+1,'vname']:
        if dff.loc[i,'URL']!='':
            dff.loc[0,'URL']+=','+dff.loc[i+1,'URL']
            
    print(dff.loc[i,'vname'])
# Out:
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# Anti-CSRF Tokens Check
# SQL Injection - SQLite
# SQL Injection - SQLite
# Application Error Disclosure
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# Content Security Policy (CSP) Header Not Set
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Missing Anti-clickjacking Header
# Missing Anti-clickjacking Header
# Missing Anti-clickjacking Header
# ...

# %%
dff
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.to_excel("maive.xlsx",index=False,header=True)
# Out:
# bar%40example.com&message&name=ZAP&phone=9999999999,https://www.secureblink.com/white-paper?email=foo-bar%40example.com&name=ZAP&phone=9999999999,https://www.secureblink.com/about-us,https://www.secureblink.com/blog,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/about-us,,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/about-us,https://www.secureblink.com/blog,https://www.secureblink.com/careers,https://www.secureblink.com/
# ...

# %%
dff.to_csv("Rave.csv",index=False,header=True)

# %%
url=dff.loc[:,'Request Header']

# %%
print(url)
# Out:
#     Request Header                                     Request Header
# 0              GET       https://www.secureblink.com/company-register
# 1              GET  https://www.secureblink.com/company-register?c...
# 2              GET             https://www.secureblink.com/contact-us
# 3              GET  https://www.secureblink.com/contact-us?company...
# 4              GET               https://www.secureblink.com/register
# ..             ...                                                ...
# 158            GET            https://www.secureblink.com/sitemap.xml
# 159            GET              https://www.secureblink.com/solutions
# 160            GET        https://www.secureblink.com/threat-research
# 161            GET             https://www.secureblink.com/threat-spy
# 162            GET            https://www.secureblink.com/white-paper
#
# [163 rows x 2 columns]

# %%
str=""

for x in url.itertuples():
    if(x[2]!=''):
        str=str+x[2]+','
#     print(x[2])

print(str)
# Out:
# bar%40example.com&message&name=ZAP&phone=9999999999,https://www.secureblink.com/white-paper?email=foo-bar%40example.com&name=ZAP&phone=9999999999,https://www.secureblink.com/,https://www.secureblink.com/about-us,https://www.secureblink.com/blog,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/,https://www.secureblink.com/about-us,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/,https://www.
# ...

# %%
li=[]
for i in range(163):
    if i==0:
        li.append(str)
    else:
        li.append('')

# %%
x=dff.assign(RequestHeader=li)

# %%
x
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
x.columns.values[4] = "Car Names"

# %%
x
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
x.drop(dff.columns[11], axis=1, inplace=True)

# %%
x
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
x.rename(columns = {'Car Names':'Request Header'}, inplace = True)

# %%
x
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
x.columns
# Out:
# Index(['vname', 'Risk level', 'Description', 'URL', 'Responce', 'Instances',
#        'Solution', 'Reference', 'Request Header'],
#       dtype='object')

# %%
x.to_excel("seperatewithcommaa.xlsx",index=False,header=True)
# Out:
# bar%40example.com&message&name=ZAP&phone=9999999999,https://www.secureblink.com/white-paper?email=foo-bar%40example.com&name=ZAP&phone=9999999999,https://www.secureblink.com/,https://www.secureblink.com/about-us,https://www.secureblink.com/blog,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/,https://www.secureblink.com/about-us,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/,https://www.
# ...

# %%
x.to_csv("amm.csv",index=False,header=True)

# %%
x.to_csv("vicky1.csv",index=False,header=True)

# %%
dfff=dff.replace('https://www.secureblink.com/company-register',str)

# %%
dfff
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dfff.to_excel("khushii1111.xlsx",index=False,header=True)
# Out:
# bar%40example.com&message&name=ZAP&phone=9999999999,https://www.secureblink.com/white-paper?email=foo-bar%40example.com&name=ZAP&phone=9999999999,https://www.secureblink.com/,https://www.secureblink.com/about-us,https://www.secureblink.com/blog,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/,https://www.secureblink.com/about-us,https://www.secureblink.com/careers,https://www.secureblink.com/contact-us,https://www.secureblink.com/cyber-security-news,https://www.secureblink.com/robots.txt,https://www.secureblink.com/solutions,https://www.secureblink.com/threat-research,https://www.secureblink.com/threat-spy,https://www.secureblink.com/white-paper,https://www.secureblink.com/,https://www.
# ...

# %%
dff.to_excel("khushii111.xlsx",index=False,header=True)

# %%
# !pip install pdfx

# %%
import pdfx
 
# reading the PDF File
pdf = pdfx.PDFx("secureblink_full.pdf")
 
# get list of URLS
print(pdf.get_references_as_dict())

# %%
dff = pd.DataFrame({'URL':pdf.get_references_as_dict()})

# %%
dff.insert({'URL':pdf.get_references_as_dict()})

# %%
 dff

# %%
# d={'url': ['https://tools.ietf.org/html/rfc1918', 'https://tools.ietf.org/html/rfc7231', 'https://www.secureblink.com/', 'https://cheatsheetseries.owasp.org/cheatsheets/SQL_Injection_Prevention_Cheat_Sheet.html', 'https://www.facebook.com/tr', 'https://www.secureblink.com/register?email=foo-bar%40example.com&name=ZAP&password=ZAP&username=ZAP', 'https://cwe.mitre.org/data/definitions/200.html', 'https://www.secureblink.com/rss-feeds', 'https://www.secureblink.com/contact-us?company=ZAP&email=foo-bar%40example.com&job=ZAP&message&name=ZAP&phone=9999999999', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10109', 'https://www.zaproxy.org/docs/alerts/10202/', 'https://cwe.mitre.org/data/definitions/319.html', 'https://cwe.mitre.org/data/definitions/89.html', 'https://www.zaproxy.org/docs/alerts/90022/', 'http://blogs.msdn.com/b/varunm/archive/2013/04/23/remove-unwanted-http-response-headers.aspx', 'https://www.zaproxy.org/docs/alerts/10020/', 'https://www.secureblink.com/cyber-security-news/sfile-', 'https://www.secureblink.com/threat-spy?email=foo-', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10015', 'https://www.zaproxy.org/docs/alerts/2/', 'http://caniuse.com/#feat=contentsecuritypolicy', 'https://owasp.org/www-community/Security_Headers', 'https://www.zaproxy.org/docs/alerts/10037/', 'https://www.zaproxy.org/docs/alerts/10024/', 'https://www.zaproxy.org/docs/alerts/10038/', 'https://www.secureblink.com/threat-research/cereberus-banking-virus', 'https://www.secureblink.com/terms-and-conditions', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10024', 'https://www.zaproxy.org/docs/alerts/10096/', 'https://www.zaproxy.org/docs/alerts/10027/', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#90022', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#40024', 'https://www.secureblink.com/robots.txt', 'https://www.secureblink.com/white-paper?email=foo-bar%40example.com&name=ZAP&phone=9999999999', 'https://www.secureblink.com', 'https://www.secureblink.com/cdn-cgi/l/email-protection', 'https://cwe.mitre.org/data/definitions/693.html', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10050', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#20012', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10202', 'https://www.secureblink.com/rss-feeds/threat-research', 'https://www.secureblink.com/threat-research/clop-ransomware', 'https://www.googletagmanager.com/gtag/js?id=UA-151054930-1', 'https://www.secureblink.com/about-us', 'https://www.secureblink.com/threat-research', 'https://www.secureblink.com/threat-research/user-datagram-protocol', 'http://en.wikipedia.org/wiki/HTTP_Strict_Transport_Security', 'https://cwe.mitre.org/data/definitions/264.html', 'http://caniuse.com/stricttransportsecurity', 'https://www.secureblink.com/careers', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10098', 'https://www.secureblink.com/cyber-security-news', 'http://www.html5rocks.com/en/tutorials/security/content-security-policy/', 'http://www.w3.org/TR/CSP/', 'https://www.zaproxy.org/docs/alerts/10017/', 'https://www.secureblink.com/cdn-cgi/styles/cf.errors.css', 'https://www.zaproxy.org/docs/alerts/10035/', 'https://www.secureblink.com/threat-research/wastedlocker-and-evil-corp', 'http://content-security-policy.com/', 'https://developer.mozilla.org/en-US/docs/Web/Security/CSP/Introducing_Content_Security_Policy', 'https://www.secureblink.com/threat-spy', 'https://www.secureblink.com/cdn-cgi/styles/cf.errors.ie.css', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10035', 'https://www.zaproxy.org/docs/alerts/10109/', 'https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/X-Frame-Options', 'https://www.secureblink.com/sitemap.xml', 'https://www.zaproxy.org/docs/alerts/10015/', 'http://projects.webappsec.org/w/page/13246936/Information%20Leakage', 'https://www.secureblink.com/threat-research/mozi-p2p-botnet-evolved-executed-new-capabilities-to-target-its-victims', 'https://www.secureblink.com/threat-research/shareit:-unpatched-vulnerability-targeting-to-remote-code-execution', 'https://www.secureblink.com/company-register', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10017', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10027', 'https://www.secureblink.com/white-paper', 'http://w3c.github.io/webappsec/specs/content-security-policy/csp-specification.dev.html', 'https://www.zaproxy.org/docs/alerts/20012/', 'https://cwe.mitre.org/data/definitions/829.html', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10020', 'https://vulncat.fortify.com/en/detail?id=desc.config.dotnet.html5_overly_permissive_cors_policy', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10037', 'https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Cache-Control', 'http://www.troyhunt.com/2012/02/shhh-dont-let-your-response-headers.html', 'http://tools.ietf.org/html/rfc6797', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#2', 'https://www.zaproxy.org/docs/alerts/40024/', 'https://cwe.mitre.org/data/definitions/525.html', 'https://www.w3.org/TR/CSP2/', 'https://w3c.github.io/webappsec-csp/', 'https://www.secureblink.com/_next/static/chunks/pages/index-ed95606da377e7c58d7a.js', 'https://cheatsheetseries.owasp.org/cheatsheets/Session_Management_Cheat_Sheet.html#web-content-caching', 'http://cwe.mitre.org/data/definitions/352.html', 'https://www.zaproxy.org/docs/alerts/10050/', 'https://cwe.mitre.org/data/definitions/1021.html', 'https://www.secureblink.com/cyber-security-news/vmware-vulnerability', 'https://www.secureblink.com/solutions', 'http://www.w3.org/Protocols/rfc2616/rfc2616-sec13.html', '40example.com', 'https://www.secureblink.com/threat-research/dorkbot-malware', 'https://www.secureblink.com/company-register?companyName=ZAP&email=foo-', 'https://www.secureblink.com/contact-us?company=ZAP&email=foo-', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10038', 'https://www.secureblink.com/cyber-security-news/moncler-group-becomes-the-first-victim-of-alphv-', 'https://www.zaproxy.org/docs/alerts/10098/', 'http://www.w3.org/Protocols/rfc2616/rfc2616-sec13.html%20(obsoleted%20by%20rfc7234)', 'https://www.secureblink.com/signin?email_or_username=ZAP&password=ZAP', 'https://www.secureblink.com/register', 'https://www.secureblink.com/blog', 'https://www.secureblink.com/threat-research/ekans-ransomware', 'https://www.secureblink.com/threat-research/the-iron-liberty-group', 'https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js', 'https://cwe.mitre.org/data/definitions/352.html', 'https://cheatsheetseries.owasp.org/cheatsheets/Content_Security_Policy_Cheat_Sheet.html', 'https://www.secureblink.com/threat-research/netwalker-ransomware', 'https://www.secureblink.com/threat-research/zloader-malware', 'https://www.secureblink.com/contact-us', 'https://www.secureblink.com/company-register?companyName=ZAP&email=foo-bar%40example.com&name=ZAP&password=ZAP', 'https://www.secureblink.com/threat-research/taidoor-malware', 'https://www.secureblink.com/threat-spy?email=foo-bar%40example.com&message&name=ZAP&phone=9999999999', 'https://tools.ietf.org/html/rfc7234', 'https://www.secureblink.com/signin', 'https://cheatsheetseries.owasp.org/cheatsheets/HTTP_Strict_Transport_Security_Cheat_Sheet.html', 'file:///home/baby/Documents/SB/24-jan/secureblink_fullscan.html#10096', 'http://projects.webappsec.org/Cross-Site-Request-Forgery']}

# %%
# dff = pd.DataFrame.from_dict(d, orient='index')
# dff.columns = ['scores']

# %%
# dff['new_col'] = pdf.get_references_as_dict()

# %%
dff

# %%
print(dff.get('URL'))

# %%
URL=dff.loc[:,'Request Header']

# %%
dff['new_col'] = dff.get('URL')

# %%
# dff['new_col']=pdf.get_references_as_dict('URL')

# %%
dff

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-687-39d9d5b12167> in <module>
#       1 for record in reader:
# ----> 2     animal_col['Request Header'].append(record['new_col'])
#
# KeyError: 'Request Header'

# %%
dff
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff['Request Header'].values.tolist()
# Out:
# [['GET', 'https://www.secureblink.com/company-register'],
#  ['GET',
#   'https://www.secureblink.com/company-register?companyName=ZAP&email=foo-\rbar%40example.com&name=ZAP&password=ZAP'],
#  ['GET', 'https://www.secureblink.com/contact-us'],
#  ['GET',
#   'https://www.secureblink.com/contact-us?company=ZAP&email=foo-\rbar%40example.com&job=ZAP&message&name=ZAP&phone=9999999999'],
#  ['GET', 'https://www.secureblink.com/register'],
#  ['GET',
#   'https://www.secureblink.com/register?email=foo-bar%40example.com&name=ZAP&password=ZAP&username=ZAP'],
#  ['GET', 'https://www.secureblink.com/signin'],
#  ['GET',
#   'https://www.secureblink.com/signin?email_or_username=ZAP&password=ZAP'],
#  ['GET', 'https://www.secureblink.com/threat-spy'],
#  ['GET',
#   'https://www.secureblink.com/threat-spy?email=foo-\rbar%40example.com&message&name=ZAP&phone=9999999999'],
#  ['GET', ''],
#  ['GET',
# ...

# %%
dfff=dff.assign(Rating=dff['Request Header'].values.tolist())

# %%
dfff
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dfff.drop('Request Header',axis = 1, inplace=True)

# %%
dfff
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dff.rename(columns = {'Rating':'Request Header'}, inplace = True)

# %%
dfff
# Out:
#                       vname     Risk level  \
# 0    Anti-CSRF Tokens Check           High
# 1    Anti-CSRF Tokens Check           High
# 2    Anti-CSRF Tokens Check           High
# 3    Anti-CSRF Tokens Check           High
# 4    Anti-CSRF Tokens Check           High
# ..                      ...            ...
# 158    Retrieved from Cache  Informational
# 159    Retrieved from Cache  Informational
# 160    Retrieved from Cache  Informational
# 161    Retrieved from Cache  Informational
# 162    Retrieved from Cache  Informational
#
#                                            Description  \
# 0    A cross-site request forgery is an attack that...
# 1    A cross-site request forgery is an attack that...
# 2    A cross-site request forgery is an attack that...
# 3    A cross-site request forgery is an attack that...
# 4    A cross-site request forgery is an attack that...
# ..                                                 ...
# ...

# %%
dfff.to_excel("khushii.xlsx",index=False,header=True)
